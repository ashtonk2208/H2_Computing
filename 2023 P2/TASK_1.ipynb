# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonk2208/H2_Computing/blob/main/TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1.1
import sqlite3
conn = sqlite3.connect('TESTDATABASE')
conn.execute('''DROP TABLE IF EXISTS Student''')
conn.execute('''DROP TABLE IF EXISTS Test''')
conn.execute('''DROP TABLE IF EXISTS Class''')
conn.execute('''DROP TABLE IF EXISTS Student_Test''')


conn.execute(''' CREATE TABLE Student(
    StudentID INTEGER PRIMARY KEY,
    GivenName TEXT,
    FamilyName TEXT,
    ClassName TEXT
    );''',())
conn.execute(''' CREATE TABLE Test(
    TestID TEXT PRIMARY KEY,
    MaxMarks INTEGER
    );''',())
conn.execute(''' CREATE TABLE Class(
    ClassName TEXT PRIMARY KEY,
    YearGroup INTEGER
    );''',())
conn.execute(''' CREATE TABLE Student_Test(
    StudentTestID INTEGER PRIMARY KEY,
    StudentID INTEGER,
    TestID TEXT,
    Mark INTEGER,
    DateTest TEXT,
    FOREIGN KEY(StudentID) REFERENCES Student(StudentID),
    FOREIGN KEY(TestID) REFERENCES Test(TestID)
    );''',())

conn.commit()
conn.close()

# %%
import sqlite3
conn = sqlite3.connect('TESTDATABASE')

conn.execute('''INSERT INTO Student
    VALUES(102,'Mary','Lim','CS3')''')
conn.execute('''INSERT INTO Class
    VALUES('CS3',12)''')
conn.execute('''INSERT INTO Test
    VALUES('PG1',100)''')
conn.execute('''INSERT INTO Student_Test
    VALUES(123,102,'PG1',85,'01-02-2023')''')
cursor = conn.execute('''SELECT *
    FROM Student_Test
    WHERE StudentTestID = ?
    ''',(123,)).fetchall()
for doc in cursor:
    print(doc)
conn.commit()
conn.close()
# Out:
# (123, 102, 'PG1', 85, '01-02-2023')
