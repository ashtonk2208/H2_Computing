# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonk2208/H2_Computing/blob/main/2020_TASK_1_ASHTONKOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1.1
def task1_1(string_value):
    h = 0
    for i in range(len(string_value)):
        val = 33* ord(string_value[i])
        h = (h + val) % 1024
    return h

print(task1_1("Hello"))
print(task1_1("Hallo"))
print(task1_1("Hullo"))
# Out:
# 116
# 1008
# 644

# %%
#Task 1.2
def task1_2(seed,string_value):
    string = seed + string_value
    return task1_1(string)

print(task1_2("seed-one","Hello"))
print(task1_2("seed-two","Hello"))
print(task1_2("seed-three","Hello"))
# Out:
# 388
# 156
# 282
